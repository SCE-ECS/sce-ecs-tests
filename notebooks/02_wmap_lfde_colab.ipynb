# %% [markdown]
# <a href="https://colab.research.google.com/github/SCE-ECS/sce-ecs-tests/blob/main/02_wmap_lfde_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SCE–ECS Tier-3 LFDE Test (CMB Example: WMAP W-band)

Denna notebook visar hur Tier-3 LFDE-reciprocitetstestet körs på
en CMB-dataset (WMAP W-band, T/Q/U) via konfigfilen `configs/wmap_wband_TQU.yaml`.

Alla dataset-specifika val (band, nside, mask, filnamn) ligger i YAML-filen.
LFDE-avatar och metrik är oförändrade mellan olika datasets.

# %%
# %cd /content
# !rm -rf sce-ecs-tests
# !git clone https://github.com/SCE-ECS/sce-ecs-tests.git
# %cd sce-ecs-tests

# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'sce-ecs-tests'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 192 (delta 15), reused 0 (delta 0), pack-reused 150 (from 1)
# Receiving objects: 100% (192/192), 82.60 KiB | 1.92 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /content/sce-ecs-tests
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 27.1 MB/s eta 0:00:00
# ...

# %%
import os, sys

# Säkerställ att vi står i repo-roten
os.chdir("/content/sce-ecs-tests")

# 1) För !python-kommandon
os.environ["PYTHONPATH"] = "/content/sce-ecs-tests/src"

# 2) För imports i notebooken
src_path = "/content/sce-ecs-tests/src"
if src_path not in sys.path:
    sys.path.append(src_path)

print("PYTHONPATH:", os.environ["PYTHONPATH"])
print("src in sys.path?", src_path in sys.path)
# Out:
# PYTHONPATH: /content/sce-ecs-tests/src
# src in sys.path? True

# %%
config_path = "configs/wmap_wband_TQU.yaml"
print("Using config:", config_path)
# Out:
# Using config: configs/wmap_wband_TQU.yaml

# %%
from sceecs_tests.config import load_config

cfg = load_config(config_path)
cfg
# Out:
# {'dataset': 'WMAP_Wband_TQU',
#  'domain': 'cmb',
#  'data_root': '/content/sce-ecs-tests/data/WMAP',
#  'files': {'T_map': 'raw/wmap_W_T.fits',
#   'Q_map': 'raw/wmap_W_Q.fits',
#   'U_map': 'raw/wmap_W_U.fits'},
#  'metadata': {'nside': 512,
#   'band': 'W',
#   'frequency_ghz': 94,
#   'beam_fwhm_arcmin': 13.2,
#   'coordinate_frame': 'galactic',
#   'mask': 'processed/kq85_mask.fits'},
#  'lfde': {'ks_values': [20, 40, 80, 160, 320, 640],
#   'output_csv': 'results/user_submitted_runs/wmap_wband_lfde.csv',
#   'output_plot': 'results/user_submitted_runs/wmap_wband_lfde.png'}}

# %%
# !python scripts/lfde_reciprocity/run_cmb_lfde_sweep.py --config {config_path}
# Out:
# Traceback (most recent call last):
#   File "/content/sce-ecs-tests/scripts/lfde_reciprocity/run_cmb_lfde_sweep.py", line 35, in <module>
#     main()
#   File "/content/sce-ecs-tests/scripts/lfde_reciprocity/run_cmb_lfde_sweep.py", line 23, in main
#     cmb = load_cmb_dataset(cfg)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/sce-ecs-tests/src/sceecs_tests/cmb_io.py", line 27, in load_cmb_dataset
#     T = load_map("T_map")
#         ^^^^^^^^^^^^^^^^^
#   File "/content/sce-ecs-tests/src/sceecs_tests/cmb_io.py", line 23, in load_map
#     raise FileNotFoundError(f"Filen hittades inte: {path}")
# FileNotFoundError: Filen hittades inte: /content/sce-ecs-tests/data/WMAP/raw/wmap_W_T.fits

# %%
import pandas as pd
from pathlib import Path

output_csv = cfg["lfde"]["output_csv"]
print("Reading CSV from:", output_csv)

csv_path = Path(output_csv)
if csv_path.exists():
    df = pd.read_csv(output_csv)
    df
else:
    print("Ingen CSV hittades (troligen inga riktiga WMAP-data ännu).")
# Out:
# Reading CSV from: results/user_submitted_runs/wmap_wband_lfde.csv
# Ingen CSV hittades (troligen inga riktiga WMAP-data ännu).

# %%
from IPython.display import Image, display
from pathlib import Path

output_plot = cfg["lfde"]["output_plot"]
print("Showing plot from:", output_plot)

plot_path = Path(output_plot)
if plot_path.exists():
    display(Image(output_plot))
else:
    print("Ingen plot hittades (troligen inga riktiga WMAP-data ännu).")
# Out:
# Showing plot from: results/user_submitted_runs/wmap_wband_lfde.png
# Ingen plot hittades (troligen inga riktiga WMAP-data ännu).

# %%
## Kommentar

- Denna notebook använder WMAP W-band-konfigurationen `configs/wmap_wband_TQU.yaml`.
- LFDE-avatar och metrik är desamma för alla CMB-datasets.
- Om CSV/plot inte skapas beror det bara på att inga riktiga WMAP-FITS ligger i
  `data/WMAP/raw/` och ingen mask i `data/WMAP/processed/`.

När användaren lägger sina riktiga WMAP-filer enligt konfigurationen,
kommer cell 6 att skapa CSV och plot automatiskt.
